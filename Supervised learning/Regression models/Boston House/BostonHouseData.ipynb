# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
def warn(*args, **kwargs):
    pass 
import warnings
warnings.warn = warn

# %%
df = pd.read_csv('HousingData.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %% [markdown]
# ### Determining Normality

# %%
df1 = df.copy()

# %%
print("Missing value pattern:")
print(df1.isnull().sum())
# Out:
# Missing value pattern:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
missing_rows = df1[df1.isnull().any(axis=1)]
print(f"Rows with missing values: {len(missing_rows)}")
print(missing_rows.head())
print("Percentage missing:", (len(df1[df1.isnull().any(axis=1)]) / len(df1)) * 100)
# Out:
# Rows with missing values: 112
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 4   0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
# 6   0.08829  12.5   7.87   NaN  0.524  6.012  66.6  5.5605    5  311     15.2
# 9   0.17004  12.5   7.87   NaN  0.524  6.004  85.9  6.5921    5  311     15.2
# 14  0.63796   0.0   8.14   NaN  0.538  6.096  84.5  4.4619    4  307     21.0
# 35  0.06417   0.0   5.96   0.0  0.499  5.933  68.2  3.3603    5  279     19.2
#
#          B  LSTAT  MEDV
# 4   396.90    NaN  36.2
# 6   395.60  12.43  22.9
# 9   386.71  17.10  18.9
# 14  380.02  10.26  18.2
# 35  396.90    NaN  18.9
# Percentage missing: 22.134387351778656

# %%
df1 = df1.dropna()

# %%
df1.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
x = df1.drop(columns="MEDV")
y = df1['MEDV']

# %%
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression 

model = LinearRegression() 
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([29.22850199, 17.5037472 , 21.80803847, 30.4942528 , 18.50265527,
#        34.7432311 , 22.07369779, 30.7541295 , 33.52029866, 14.82910783,
#        22.14507214, 41.26427356, 22.51242483, 16.87300668, 19.0023074 ,
#        20.77110711, 17.26921288, 15.48568273, 22.69482862, 14.12652975,
#        18.19319969, 20.48292217, 17.04235173, 29.66737037, 26.09718411,
#        16.06132841, 27.09746911, 31.45656662, 22.64238912, 27.06681913,
#        41.10181897, 18.21320236, 23.062681  , 17.41202659, 17.39546606,
#        21.076803  , 22.38598488, 21.66963934, 22.9118984 , 20.80249561,
#        27.70046219, 34.60121409, 22.25931447, 30.83868791, 35.33229137,
#        19.76393425, 24.99195034, 10.39133132, 19.75538217, 25.31114768,
#        21.55934818, 25.89776968, 14.23212614, 18.66822307, 18.34126683,
#        24.31756905, 43.40891373, 22.87668508, 15.3452895 , 23.17268086,
#        21.11796307, 21.4821572 , 14.66508216, 28.92300146, -3.71655126,
# ...

# %%
from sklearn.metrics import r2_score, mean_squared_error

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred) 

print(mse)
print(r2*100)
# Out:
# 31.454047664950856
# 62.70849941673193

# %%
df1.head(1)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.09    1  296     15.3
#
#        B  LSTAT  MEDV
# 0  396.9   4.98  24.0

# %%
new_data = [[0.001, 20, 3, 1, 1, 5, 22, 4, 2, 300, 16, 400, 5]]

prediction = model.predict(new_data)
prediction
# Out:
# array([17.75117812])

# %%
import os 
os.getcwd()
# Out:
# '/Users/awabe/Documents/ML foundation to Advance/Certisured course/Machine Learning/Projects for GITHUB/LinearRegression/Boston House'

# %%
import joblib 

joblib.dump(model, 'Boston_regression_model.pkl')
# Out:
# ['Boston_regression_model.pkl']
